# %%
from tkinter import *
from tkinter import ttk,PhotoImage
from tkinter.ttk import Combobox
from tkinter.filedialog import askopenfilename
from tkinter.messagebox import askretrycancel
import pandas as pd
from classification import clasif
from regresion import reg
# %reload_ext autoreload
# %autoreload 2

# %%
Det = Tk()
Det.title("Login")  
Det.geometry('1800x1200')

scrollbar = Scrollbar(Det)
scrollbar.pack(side = RIGHT, fill = Y )

frm2 = Frame(Det,bg='#34495E', width=1800, height=1200)
frm2.pack()

# Canvas
canvas1 = Canvas(frm2, width = 1800, height = 1200, bg='#58FE03', bd=0, highlightthickness=0,yscrollcommand = scrollbar.set)       
canvas1.place(x=0,y=0) 
canvas1.create_image(1800,1200,anchor=CENTER)



lbl1 = Label(Det,font=("Forte","32"), bg='#2FF1D2',text="Welcome To The Login Page !")
lbl1.place(x=520, y=75)

 # Name
lbl2 = Label(Det,font=("Times","12"),bg='#2FF1D2', text="E-mail")
lbl2.place(x=600, y=215)
# # Name-Textbox:
txt1 = Entry(Det, width=25)
txt1.place(x=700, y=215)
# # password:
lbl3 = Label(Det,font=("Times","12"),bg='#2FF1D2', text="Password")
lbl3.place(x=600, y=255)
# # Password-Textbox:
txt2 = Entry(Det, width=25)
txt2.place(x=700, y=255)

def clicked():
    tsk = Tk()
    tsk.title("dddd")  
    tsk.geometry('1800x12000')
    frm3 = Frame(tsk,bg='#34495E', width=1800, height=1200)
    frm3.pack()
    # Canvas
    canvas2 = Canvas(frm3, width = 1800, height = 1200, bg='#58FE03', bd=0, highlightthickness=0)       
    canvas2.place(x=0,y=0) 
    canvas2.create_image(1800,1200,anchor=CENTER)

    lbl1 = Label(tsk,font=("Sain Serif","32"), bg='#2FF1D2',text="Select Your Choice !")
    lbl1.place(x=520, y=75)

    def Clasi():
        # Package Importing of Classification:
        O2 = clasif()
        O2.winloop()
    def Regre():
        O3 = reg()
        O3.winregloop()
    
    # Classification Button:
    btn = Button(tsk,font=("Sain Serif", "14", "bold italic"), width=15, height=1, text="Classification",command=Clasi)
    btn.place(x=520, y=155)

    # Regression Button:
    btn = Button(tsk,font=("Sain Serif", "14", "bold italic"), width=15, height=1, text="Regression",command=Regre)
    btn.place(x=720, y=155)
    tsk.mainloop()
    

btn = Button(Det,font=("Times", "12", "bold italic"),bg='#2FF1D2', width=6, height=1, text="Submit",command=clicked)
btn.place(x=700, y=295)

scrollbar.config( command = canvas1.yview )

Det.mainloop()
